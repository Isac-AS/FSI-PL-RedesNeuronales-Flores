# %% [markdown]
# # Preparación
# Se monta el sistema de archivos de google drive.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 2022-01-08 21:38:45.944207: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# '/device:GPU:0'
# 2022-01-08 21:38:45.944959: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:38:45.945486: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:38:45.946037: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:38:45.946384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:38:45.946662: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('../input/flowers-recognition/flowers/daisy/100080576_f52e8ee070_n.jpg', 'r')
imshow(np.asarray(pil_im))

# %% [markdown]
# # Carga del dataset

# %%
image_size = (150, 150)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten, BatchNormalization, GlobalAveragePooling2D

# %%
model = keras.Sequential()
model.add(Rescaling(scale=(1./255),
                    input_shape=(150, 150, 3)))


model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(96, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(128, kernel_size=(5, 5), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())
model.add(Dense(5, activation='softmax'))

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
              metrics=['accuracy'])

# %% [markdown]
# # Visualización del modelo

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# # Entrenamiento

# %%
from keras.callbacks import EarlyStopping

epochs = 150

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10,
                   restore_best_weights=True)

h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/150
# 108/108 [==============================] - 7s 57ms/step - loss: 1.5367 - accuracy: 0.2892 - val_loss: 1.4248 - val_accuracy: 0.3859
# Epoch 2/150
# 108/108 [==============================] - 7s 58ms/step - loss: 1.2433 - accuracy: 0.4586 - val_loss: 1.2581 - val_accuracy: 0.4936
# Epoch 3/150
# 108/108 [==============================] - 7s 61ms/step - loss: 1.1840 - accuracy: 0.4896 - val_loss: 1.1615 - val_accuracy: 0.5400
# Epoch 4/150
# 108/108 [==============================] - 6s 57ms/step - loss: 1.1019 - accuracy: 0.5420 - val_loss: 1.1365 - val_accuracy: 0.5562
# Epoch 5/150
# 108/108 [==============================] - 6s 57ms/step - loss: 1.0393 - accuracy: 0.5825 - val_loss: 1.0685 - val_accuracy: 0.5747
# Epoch 6/150
# 108/108 [==============================] - 7s 63ms/step - loss: 0.9802 - accuracy: 0.6120 - val_loss: 0.9995 - val_accuracy: 0.6292
# Epoch 7/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.8962 - accuracy: 0.6511 - val_loss: 0.9781 - val_accuracy: 0.6280
# Epoch 8/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.8490 - accuracy: 0.6740 - val_loss: 0.9071 - val_accuracy: 0.6651
# Epoch 9/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.8216 - accuracy: 0.6847 - val_loss: 1.0068 - val_accuracy: 0.6049
# Epoch 10/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.7763 - accuracy: 0.7044 - val_loss: 0.8747 - val_accuracy: 0.6640
# Epoch 11/150
# 108/108 [==============================] - 7s 62ms/step - loss: 0.7697 - accuracy: 0.7076 - val_loss: 0.8764 - val_accuracy: 0.6860
# Epoch 12/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.7308 - accuracy: 0.7244 - val_loss: 0.9321 - val_accuracy: 0.6385
# Epoch 13/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.7263 - accuracy: 0.7244 - val_loss: 0.8575 - val_accuracy: 0.6744
# Epoch 14/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.6814 - accuracy: 0.7394 - val_loss: 0.8405 - val_accuracy: 0.6813
# Epoch 15/150
# 108/108 [==============================] - 7s 61ms/step - loss: 0.6660 - accuracy: 0.7499 - val_loss: 0.9386 - val_accuracy: 0.6431
# Epoch 16/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.6494 - accuracy: 0.7554 - val_loss: 0.8076 - val_accuracy: 0.7092
# Epoch 17/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.6493 - accuracy: 0.7583 - val_loss: 0.9591 - val_accuracy: 0.6524
# Epoch 18/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.6226 - accuracy: 0.7690 - val_loss: 0.8051 - val_accuracy: 0.7045
# Epoch 19/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5922 - accuracy: 0.7785 - val_loss: 0.8161 - val_accuracy: 0.6918
# Epoch 20/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.6250 - accuracy: 0.7727 - val_loss: 0.8047 - val_accuracy: 0.6895
# Epoch 21/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.5831 - accuracy: 0.7849 - val_loss: 0.8396 - val_accuracy: 0.6779
# Epoch 22/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.5577 - accuracy: 0.7950 - val_loss: 0.7815 - val_accuracy: 0.7092
# Epoch 23/150
# 108/108 [==============================] - 7s 63ms/step - loss: 0.5461 - accuracy: 0.7947 - val_loss: 0.7647 - val_accuracy: 0.7207
# Epoch 24/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5368 - accuracy: 0.8057 - val_loss: 0.7877 - val_accuracy: 0.7173
# Epoch 25/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.5293 - accuracy: 0.8095 - val_loss: 0.9811 - val_accuracy: 0.6535
# Epoch 26/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.5125 - accuracy: 0.8104 - val_loss: 0.7436 - val_accuracy: 0.7231
# Epoch 27/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.5028 - accuracy: 0.8133 - val_loss: 0.7502 - val_accuracy: 0.7289
# Epoch 28/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4926 - accuracy: 0.8199 - val_loss: 0.7192 - val_accuracy: 0.7358
# Epoch 29/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4787 - accuracy: 0.8246 - val_loss: 0.8018 - val_accuracy: 0.7034
# Epoch 30/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4656 - accuracy: 0.8286 - val_loss: 0.7096 - val_accuracy: 0.7393
# Epoch 31/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4492 - accuracy: 0.8356 - val_loss: 0.7640 - val_accuracy: 0.7323
# Epoch 32/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.4113 - accuracy: 0.8506 - val_loss: 0.7240 - val_accuracy: 0.7393
# Epoch 33/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.4031 - accuracy: 0.8541 - val_loss: 0.7846 - val_accuracy: 0.7312
# Epoch 34/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4381 - accuracy: 0.8419 - val_loss: 0.7318 - val_accuracy: 0.7231
# Epoch 35/150
# 108/108 [==============================] - 7s 59ms/step - loss: 0.3869 - accuracy: 0.8625 - val_loss: 0.7064 - val_accuracy: 0.7404
# Epoch 36/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3934 - accuracy: 0.8616 - val_loss: 0.6943 - val_accuracy: 0.7567
# Epoch 37/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.3743 - accuracy: 0.8657 - val_loss: 0.6944 - val_accuracy: 0.7520
# Epoch 38/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3711 - accuracy: 0.8660 - val_loss: 0.7483 - val_accuracy: 0.7462
# Epoch 39/150
# 108/108 [==============================] - 7s 57ms/step - loss: 0.3408 - accuracy: 0.8787 - val_loss: 0.8499 - val_accuracy: 0.7219
# Epoch 40/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3421 - accuracy: 0.8758 - val_loss: 0.7431 - val_accuracy: 0.7381
# Epoch 41/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3026 - accuracy: 0.8914 - val_loss: 0.7551 - val_accuracy: 0.7474
# Epoch 42/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3015 - accuracy: 0.8897 - val_loss: 0.7038 - val_accuracy: 0.7636
# Epoch 43/150
# 108/108 [==============================] - 7s 59ms/step - loss: 0.3085 - accuracy: 0.8900 - val_loss: 0.7549 - val_accuracy: 0.7578
# Epoch 44/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.2984 - accuracy: 0.8868 - val_loss: 0.6682 - val_accuracy: 0.7706
# Epoch 45/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.2866 - accuracy: 0.8946 - val_loss: 0.7541 - val_accuracy: 0.7555
# Epoch 46/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.2811 - accuracy: 0.8935 - val_loss: 0.8199 - val_accuracy: 0.7323
# Epoch 47/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.2666 - accuracy: 0.9001 - val_loss: 0.7242 - val_accuracy: 0.7578
# Epoch 48/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.2706 - accuracy: 0.9024 - val_loss: 0.7977 - val_accuracy: 0.7590
# Epoch 49/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.2455 - accuracy: 0.9105 - val_loss: 0.7324 - val_accuracy: 0.7659
# Epoch 50/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2642 - accuracy: 0.9021 - val_loss: 0.7297 - val_accuracy: 0.7648
# Epoch 51/150
# 108/108 [==============================] - 7s 55ms/step - loss: 0.2455 - accuracy: 0.9039 - val_loss: 0.7255 - val_accuracy: 0.7717
# Epoch 52/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.2506 - accuracy: 0.9102 - val_loss: 0.8400 - val_accuracy: 0.7486
# Epoch 53/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.2450 - accuracy: 0.9007 - val_loss: 0.7376 - val_accuracy: 0.7752
# Epoch 54/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.2447 - accuracy: 0.9076 - val_loss: 0.7689 - val_accuracy: 0.7509
# Epoch 55/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.2131 - accuracy: 0.9282 - val_loss: 0.7722 - val_accuracy: 0.7543
# Epoch 56/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2074 - accuracy: 0.9256 - val_loss: 0.7557 - val_accuracy: 0.7636
# Epoch 57/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.2059 - accuracy: 0.9184 - val_loss: 0.8406 - val_accuracy: 0.7509
# Epoch 58/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2080 - accuracy: 0.9250 - val_loss: 0.7919 - val_accuracy: 0.7590
# Epoch 59/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.1932 - accuracy: 0.9334 - val_loss: 0.7408 - val_accuracy: 0.7879
# Epoch 60/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.1806 - accuracy: 0.9317 - val_loss: 0.7959 - val_accuracy: 0.7764
# Epoch 61/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.1624 - accuracy: 0.9421 - val_loss: 0.8453 - val_accuracy: 0.7683
# Epoch 62/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.1821 - accuracy: 0.9308 - val_loss: 0.8331 - val_accuracy: 0.7671
# Epoch 63/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.1987 - accuracy: 0.9259 - val_loss: 0.7715 - val_accuracy: 0.7729
# Epoch 64/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.1719 - accuracy: 0.9389 - val_loss: 0.8348 - val_accuracy: 0.7683
# Epoch 65/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.2119 - accuracy: 0.9233 - val_loss: 0.7745 - val_accuracy: 0.7822
# Epoch 66/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.1552 - accuracy: 0.9409 - val_loss: 0.8218 - val_accuracy: 0.7752
# Epoch 67/150
# 108/108 [==============================] - 7s 61ms/step - loss: 0.1523 - accuracy: 0.9430 - val_loss: 0.7669 - val_accuracy: 0.7833
# Epoch 68/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.1337 - accuracy: 0.9517 - val_loss: 0.8091 - val_accuracy: 0.7740
# Epoch 69/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.1494 - accuracy: 0.9461 - val_loss: 0.8460 - val_accuracy: 0.7659
# Restoring model weights from the end of the best epoch.
# Epoch 00069: early stopping

# %% [markdown]
# # Gráfica de evolución de pérdida y exactitud durante el entrenamiento

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss', 'val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación de los resultados

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.7445    0.7500    0.7473       136
#            1     0.8846    0.7782    0.8280       266
#            2     0.6887    0.7939    0.7376       131
#            3     0.8267    0.8732    0.8493       142
#            4     0.7487    0.7606    0.7546       188
#
#     accuracy                         0.7879       863
#    macro avg     0.7786    0.7912    0.7834       863
# weighted avg     0.7937    0.7879    0.7891       863

# %%
img = keras.preprocessing.image.load_img(
    '../input/flowers-recognition/flowers/daisy/10172636503_21bededa75_n.jpg', target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(np.argmax(predictions[0]))
# Out:
# 1
