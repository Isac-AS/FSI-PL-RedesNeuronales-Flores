# %% [markdown]
# # Preparación
# Se monta el sistema de archivos de google drive.

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# 2022-01-08 21:21:11.980097: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:21:11.980692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:21:11.981083: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:21:11.981680: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:21:11.982085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-01-08 21:21:11.982419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# '/device:GPU:0'

# %%
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image

# %matplotlib inline
pil_im = Image.open('../input/flowers-recognition/flowers/daisy/100080576_f52e8ee070_n.jpg', 'r')
imshow(np.asarray(pil_im))

# %% [markdown]
# # Carga del dataset

# %%
image_size = (150, 150)
batch_size = 32

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="training",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    "../input/flowers-recognition/flowers",
    validation_split=0.2,
    subset="validation",
    seed=1337,
    image_size=image_size,
    batch_size=batch_size,
    label_mode='categorical'
)

train_ds = train_ds.prefetch(buffer_size=32)
val_ds = val_ds.prefetch(buffer_size=32)
# Out:
# Found 4317 files belonging to 5 classes.
# Using 3454 files for training.
# Found 4317 files belonging to 5 classes.
# Using 863 files for validation.

# %% [markdown]
# # Modelo

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, Rescaling, Flatten, BatchNormalization, GlobalAveragePooling2D

# %%
model = keras.Sequential()
model.add(Rescaling(scale=(1./127.5),
                    offset=-1,
                    input_shape=(150, 150, 3)))


model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(96, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(96, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.2))
model.add(GlobalAveragePooling2D())
model.add(Dense(5, activation='softmax'))

model.compile(loss=tf.keras.losses.categorical_crossentropy,
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %% [markdown]
# # Visualización del modelo

# %%
from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_plot.png', show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# # Entrenamiento

# %%
from keras.callbacks import EarlyStopping

epochs = 150

es = EarlyStopping(monitor='val_accuracy', mode='max', verbose=1, patience=10,
                   restore_best_weights=True)

h = model.fit(
        train_ds,
        epochs=epochs, 
        validation_data=val_ds,
        callbacks = [es]
)
# Out:
# Epoch 1/150
# 108/108 [==============================] - 7s 59ms/step - loss: 1.3638 - accuracy: 0.3778 - val_loss: 1.2841 - val_accuracy: 0.4913
# Epoch 2/150
# 108/108 [==============================] - 7s 60ms/step - loss: 1.1786 - accuracy: 0.4829 - val_loss: 1.2043 - val_accuracy: 0.5585
# Epoch 3/150
# 108/108 [==============================] - 6s 54ms/step - loss: 1.0758 - accuracy: 0.5588 - val_loss: 1.0963 - val_accuracy: 0.5643
# Epoch 4/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.9918 - accuracy: 0.6051 - val_loss: 1.0644 - val_accuracy: 0.5435
# Epoch 5/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.9197 - accuracy: 0.6413 - val_loss: 0.9952 - val_accuracy: 0.5944
# Epoch 6/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.8957 - accuracy: 0.6407 - val_loss: 0.9767 - val_accuracy: 0.6292
# Epoch 7/150
# 108/108 [==============================] - 7s 63ms/step - loss: 0.8634 - accuracy: 0.6656 - val_loss: 0.9720 - val_accuracy: 0.5991
# Epoch 8/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.8229 - accuracy: 0.6749 - val_loss: 0.9571 - val_accuracy: 0.6338
# Epoch 9/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.7947 - accuracy: 0.6995 - val_loss: 0.9601 - val_accuracy: 0.6246
# Epoch 10/150
# 108/108 [==============================] - 7s 59ms/step - loss: 0.7764 - accuracy: 0.7076 - val_loss: 0.9383 - val_accuracy: 0.6246
# Epoch 11/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.7667 - accuracy: 0.7116 - val_loss: 0.9374 - val_accuracy: 0.6234
# Epoch 12/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.7297 - accuracy: 0.7212 - val_loss: 0.9022 - val_accuracy: 0.6466
# Epoch 13/150
# 108/108 [==============================] - 7s 57ms/step - loss: 0.7315 - accuracy: 0.7212 - val_loss: 0.8600 - val_accuracy: 0.6663
# Epoch 14/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.7023 - accuracy: 0.7383 - val_loss: 0.8772 - val_accuracy: 0.6628
# Epoch 15/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.6840 - accuracy: 0.7415 - val_loss: 0.8706 - val_accuracy: 0.6640
# Epoch 16/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.7090 - accuracy: 0.7397 - val_loss: 0.8244 - val_accuracy: 0.6802
# Epoch 17/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.6664 - accuracy: 0.7536 - val_loss: 0.9246 - val_accuracy: 0.6408
# Epoch 18/150
# 108/108 [==============================] - 7s 57ms/step - loss: 0.6515 - accuracy: 0.7554 - val_loss: 0.8498 - val_accuracy: 0.6698
# Epoch 19/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.6369 - accuracy: 0.7617 - val_loss: 0.9030 - val_accuracy: 0.6616
# Epoch 20/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.6351 - accuracy: 0.7690 - val_loss: 0.8376 - val_accuracy: 0.6895
# Epoch 21/150
# 108/108 [==============================] - 7s 56ms/step - loss: 0.6083 - accuracy: 0.7791 - val_loss: 0.8064 - val_accuracy: 0.6918
# Epoch 22/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.5935 - accuracy: 0.7814 - val_loss: 0.8083 - val_accuracy: 0.6883
# Epoch 23/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.5865 - accuracy: 0.7823 - val_loss: 0.8334 - val_accuracy: 0.6756
# Epoch 24/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.5857 - accuracy: 0.7887 - val_loss: 0.8794 - val_accuracy: 0.6570
# Epoch 25/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.5778 - accuracy: 0.7944 - val_loss: 0.9453 - val_accuracy: 0.6512
# Epoch 26/150
# 108/108 [==============================] - 7s 61ms/step - loss: 0.5692 - accuracy: 0.7889 - val_loss: 0.7707 - val_accuracy: 0.7277
# Epoch 27/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.5506 - accuracy: 0.8031 - val_loss: 0.7711 - val_accuracy: 0.7219
# Epoch 28/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.5500 - accuracy: 0.7939 - val_loss: 0.7469 - val_accuracy: 0.7254
# Epoch 29/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.5498 - accuracy: 0.7930 - val_loss: 0.7560 - val_accuracy: 0.7242
# Epoch 30/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.5178 - accuracy: 0.8153 - val_loss: 0.7443 - val_accuracy: 0.7184
# Epoch 31/150
# 108/108 [==============================] - 7s 57ms/step - loss: 0.5051 - accuracy: 0.8179 - val_loss: 0.8032 - val_accuracy: 0.7103
# Epoch 32/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4980 - accuracy: 0.8222 - val_loss: 0.7390 - val_accuracy: 0.7358
# Epoch 33/150
# 108/108 [==============================] - 7s 62ms/step - loss: 0.5011 - accuracy: 0.8150 - val_loss: 0.8240 - val_accuracy: 0.6952
# Epoch 34/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.4877 - accuracy: 0.8205 - val_loss: 0.7427 - val_accuracy: 0.7161
# Epoch 35/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4872 - accuracy: 0.8234 - val_loss: 0.7638 - val_accuracy: 0.7173
# Epoch 36/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4759 - accuracy: 0.8329 - val_loss: 0.7353 - val_accuracy: 0.7289
# Epoch 37/150
# 108/108 [==============================] - 6s 53ms/step - loss: 0.4733 - accuracy: 0.8318 - val_loss: 0.8205 - val_accuracy: 0.6941
# Epoch 38/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.4568 - accuracy: 0.8335 - val_loss: 0.7523 - val_accuracy: 0.7323
# Epoch 39/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.4595 - accuracy: 0.8361 - val_loss: 1.0247 - val_accuracy: 0.6663
# Epoch 40/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4640 - accuracy: 0.8324 - val_loss: 0.7003 - val_accuracy: 0.7358
# Epoch 41/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.4274 - accuracy: 0.8451 - val_loss: 0.7389 - val_accuracy: 0.7428
# Epoch 42/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.4132 - accuracy: 0.8474 - val_loss: 0.7150 - val_accuracy: 0.7486
# Epoch 43/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4275 - accuracy: 0.8408 - val_loss: 0.7831 - val_accuracy: 0.7231
# Epoch 44/150
# 108/108 [==============================] - 7s 58ms/step - loss: 0.4072 - accuracy: 0.8512 - val_loss: 0.6913 - val_accuracy: 0.7578
# Epoch 45/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.4123 - accuracy: 0.8451 - val_loss: 0.7748 - val_accuracy: 0.7289
# Epoch 46/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.4133 - accuracy: 0.8480 - val_loss: 0.7279 - val_accuracy: 0.7381
# Epoch 47/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.3880 - accuracy: 0.8587 - val_loss: 0.7772 - val_accuracy: 0.7231
# Epoch 48/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.4240 - accuracy: 0.8503 - val_loss: 0.7374 - val_accuracy: 0.7370
# Epoch 49/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.3693 - accuracy: 0.8633 - val_loss: 0.7442 - val_accuracy: 0.7393
# Epoch 50/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3782 - accuracy: 0.8613 - val_loss: 0.6818 - val_accuracy: 0.7590
# Epoch 51/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3862 - accuracy: 0.8587 - val_loss: 0.6856 - val_accuracy: 0.7486
# Epoch 52/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3596 - accuracy: 0.8686 - val_loss: 0.7470 - val_accuracy: 0.7509
# Epoch 53/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3534 - accuracy: 0.8752 - val_loss: 0.6736 - val_accuracy: 0.7787
# Epoch 54/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3535 - accuracy: 0.8633 - val_loss: 0.7471 - val_accuracy: 0.7277
# Epoch 55/150
# 108/108 [==============================] - 7s 63ms/step - loss: 0.3483 - accuracy: 0.8703 - val_loss: 0.7705 - val_accuracy: 0.7404
# Epoch 56/150
# 108/108 [==============================] - 6s 55ms/step - loss: 0.3377 - accuracy: 0.8732 - val_loss: 0.7797 - val_accuracy: 0.7404
# Epoch 57/150
# 108/108 [==============================] - 6s 57ms/step - loss: 0.3466 - accuracy: 0.8804 - val_loss: 0.7737 - val_accuracy: 0.7451
# Epoch 58/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3349 - accuracy: 0.8830 - val_loss: 0.6962 - val_accuracy: 0.7671
# Epoch 59/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.3290 - accuracy: 0.8767 - val_loss: 0.6737 - val_accuracy: 0.7648
# Epoch 60/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3236 - accuracy: 0.8775 - val_loss: 0.7718 - val_accuracy: 0.7486
# Epoch 61/150
# 108/108 [==============================] - 6s 54ms/step - loss: 0.3186 - accuracy: 0.8819 - val_loss: 0.7492 - val_accuracy: 0.7404
# Epoch 62/150
# 108/108 [==============================] - 6s 56ms/step - loss: 0.3217 - accuracy: 0.8816 - val_loss: 0.8175 - val_accuracy: 0.7370
# Epoch 63/150
# 108/108 [==============================] - 7s 60ms/step - loss: 0.3062 - accuracy: 0.8880 - val_loss: 0.7103 - val_accuracy: 0.7532
# Restoring model weights from the end of the best epoch.
# Epoch 00063: early stopping

# %% [markdown]
# # Gráfica de evolución de pérdida y exactitud durante el entrenamiento

# %%
import matplotlib.pyplot as plt

plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.plot(h.history['loss'])
plt.plot(h.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training', 'validation','loss', 'val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# # Evaluación de los resultados

# %%
import numpy as np
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

results = np.concatenate([(y, model.predict(x=x)) for x, y in val_ds], axis=1)

predictions = np.argmax(results[0], axis=1)
labels = np.argmax(results[1], axis=1)

cf_matrix = confusion_matrix(labels, predictions)

sns.heatmap(cf_matrix, annot=True, fmt="d", cmap="Blues")

print(classification_report(labels, predictions, digits = 4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.6715    0.8440    0.7480       109
#            1     0.8974    0.7266    0.8031       289
#            2     0.7285    0.7285    0.7285       151
#            3     0.8400    0.8025    0.8208       157
#            4     0.7016    0.8535    0.7701       157
#
#     accuracy                         0.7787       863
#    macro avg     0.7678    0.7910    0.7741       863
# weighted avg     0.7933    0.7787    0.7803       863

# %%
img = keras.preprocessing.image.load_img(
    '../input/flowers-recognition/flowers/daisy/10172636503_21bededa75_n.jpg', target_size=image_size
)
img_array = keras.preprocessing.image.img_to_array(img)
img_array = tf.expand_dims(img_array, 0)  # Create batch axis

predictions = model.predict(img_array)
print(np.argmax(predictions[0]))
# Out:
# 0
